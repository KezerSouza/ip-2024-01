# %% [markdown]
# Questão 1
#   Leia Nota1, Nota2, Nota3
#   Escreva Média: (Nota1+Nota2+Nota3)/3
#   Se ((Nota1+Nota2+Nota3)/3) é maior ou igual a 6.0
#     Escreva APROVADO
#   Senão
#     Escreva REPROVADO
#
# Questão 2
#   Leia (n)
#   preço_P <- 1
#   preço_G <- 5
#   preço_A <- 10
#   preço_C <- 20
#   x <- 1
#   Enquanto n for maior que 0
#     Leia(pessoas, pessoas_P, pessoas_G, pessoas_A, pessoas_C)
#     renda_P <- pessoas*pessoas_P/100
#     renda_G <- pessoas*pessoas_G/100*5
#     renda_A <- pessoas*pessoas_A/100*10
#     renda_C <- pessoas*pessoas_C/100*20
#     renda_total <- renda_P + renda_G + renda_A + renda_C
#     Escreva A RENDA DO JOGO N x E = renda_total
#     x <- x+1
#     n <- n-1
#
# Questão 3
#   Leia n1, n2, n3
#   Se n1 ou n2 ou n3 não for inteiro
#     Escreva DIGITO INVÁLIDO
#     Encerrar execução
#   Se n1 ou n2 ou n3 for for maior que 9
#     Escreva DIGITO INVÁLIDO
#     Encerrar execução
#   concatenação <- n1, n2, n3
#   Escreva concatenação, concatenação ao quadrado
#
# Questão 4
#   Leia (salário, kw)
#   custo_por_kw <-  (70% do salário dividido por 100)
#   Escreva Custo por kw: custo_por_kw
#   Escreva Custo do consumo:  kw multiplicado por custo_por_kw
#   Custo com desconto: kw multiplicado por custo_por_kw multiplicado por 0.9
#
# Questão 5
#   Leia (num_conta, y, tipo)
#   Se "tipo" for R
#     valor <- 5 + 0,05*y
#     Escreva valor
#   Se "tipo" for C
#     Se y for maior que 80
#       valor <- 500 + 0,25*(y-80)
#       Escreva valor
#     Se y for menor ou igual a 80
#       valor <- 500
#       Escreva valor
#   Se "tipo" for I
#     Se y for maior que 100
#       valor <- 800 + 0.04*(y-100)
#       Escreva valor
#     Se y for menor ou igual a 100
#       valor <- 800
#       Escreva valor
#
#
# Questão 6
#   Leia (n)
#   Enquanto n for maior que 0
#     fahrenheit <- Leia (próxima linha)
#     celsius <- [5*(F-32)]/9
#     Escreva fahrenheit FAHRENHEIT EQUIVALE A celsius CELSIUS
#     n <- n - 1
#
# Questão 7
#   Leia (fahrenheit, pol)
#   X <- (5fahrenheit − 160)/9
#   Y <- pol*25.4
#   Escreva O VALOR EM CELSIUS = X
#   Escreva A QUANTIDADE DE CHUVA E = Y
#
# Questão 8
#   Leia (raio, altura)
#   pi <- 3,14159
#   At <- 2*pi*raio * (raio+altura)
#   Escreva O VALOR DO CUSTO E (At*100)
#
# Questão 9
#   Leia (A, B, C)
#   X <- B**2 - 4*A*C
#   Escreva O VALOR DE DELTA E = X
#
# Questão 10
#   Leia (a, b, c, d)
#   determinante <- ad - bc
#   Escreva O VALOR DA DETERMINANTE E = determinante
#
# Questão 11
#   Leia (num)
#   soma <- soma dos algarismos de num
#   Se: soma/3 o resto for 0 E soma/5 o resto for 0
#     Escreva O NUMERO E DIVISIVEL
#   Senão
#     Escreva O NUMERO NAO E DIVISIVEL
#
# Questão 12
#   Leia (horas)
#   Se horas for menor que 3
#     valor <- 5*horas
#   Se horas for maior ou igual a 3
#     valor <- [(horas-2)/3]*10 + 10
#   Escreva O VALOR A PAGAR E = valor
#
# Questão 13
#   Leia (nota)
#   Se nota for maior ou igual a 9
#     conceito <- A
#   Se nota for maior ou igual a 7.5 e menor que 9
#     conceito <- B
#   Se nota for maior ou igual a 6 e menor que 7.5
#     conceito <- C
#   Se nota for menor que 6
#     conceito <- D
#   Escreva NOTA = nota CONCEITO = conceito
#
# Questão 14
#   Leia (altura, aresta)
#   Ab <- [3*(aresta**2)*✓3]/2
#   Volume <- 1/3*Ab*altura
#   Escreva O VOLUME DA PIRAMIDE E = Volume METROS CUBICOS
#
# Questão 15
#   Leia (n)
#   Se n estiver entre 5 e 2000
#     Se n for par
#       Escreva n^2 = n**2
#       Enquanto n for maior que 2
#         Escreva (n-2)^2 = (n-2)**2
#         n <- n-2
#     Se n for ímpar
#       n <- n-1
#       Escreva n^2 = n**2
#       Enquanto n for maior que 2
#         Escreva (n-2)^2 = (n-2)**2
#         n <- n-2
#
# Questão 16
#   Leia (salário)
#   Se salário for menor ou igual a 300
#     x <- salário*1,5
#     Escreva SALARIO COM REAJUSTE = x
#   Se salário for maior que 300
#     x <- salário*1,3
#     Escreva SALARIO COM REAJUSTE = x
#
# Questão 17
#   Leia(x, y)
#   Se x dividido por 2 tiver resto 0
#     Escreva x
#     Enquanto y for maior que 1
#       x <- x+2
#       Escreva x
#       y <- y-1
#   Senão
#     Escreva O PRIMEIRO NUMERO NAO E PAR
#
#
# Questão 18
#   Leia (a1, r, n)
#   Escreva a1*n + {[(n-1)*n]/2}*r
#
# Questão 19
#   Leia (n)
#   x <- 1
#   Enquanto n for maior que 1
#     x <- x + 1/n
#     n <- n - 1
#   Escreva x
#
# Questão 20
#   Leia (hora, minuto, segundo)
#   Resultado <-   (hora*3600 + minuto*60 + segundo)
#   Escreva <- Resultado
